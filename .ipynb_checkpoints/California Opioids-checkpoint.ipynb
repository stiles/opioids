# %% [markdown]
# # Opioid distribution in California
#
# This notebook documents the Los Angeles Times' analysis of U.S. Drug Enforcement Agency data released by The Washington Post in July 2019 as part of an [investigation of opioids distribution](https://www.washingtonpost.com/graphics/2019/investigations/dea-pain-pill-database/?utm_term=.9717a00308fe) nationwide. The data, pulled from the agency's Automation of Reports and Consolidated Order System, known as ARCOS, show prescription pain pill transactions from manufacurers to distributors from 2006 to 2012. During that time, more than 8 billion tablets of hydrocodone and oxycodone were distributed to California.

# %% [markdown]
# ### To begin, load python libraries and set config params

# %%
import pandas as pd
import psycopg2 as pg
import matplotlib as mpl
from matplotlib import pyplot as plt
from matplotlib import rc
# %matplotlib inline
import seaborn as sns
import sqlalchemy
import pandas.io.sql as psql
import numpy as np
import geopandas 
import descartes
import geojson

# plt.rcParams['figure.figsize'] = [8, 4.5]
plt.rcParams['figure.figsize'] = (20, 10)
rc('font',**{'family':'sans-serif','sans-serif':['DejaVu Sans'],'size':10})
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

sorted(mpl.style.available)
# Out:
# ['Solarize_Light2',
#  '_classic_test',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %% [markdown]
# ### Connect to the local posgres server with California data

# %%
database = pg.connect("dbname=opioids user=postgres")

# %% [markdown]
# ### Query database to create dataframe for analysis with python and pandas

# %%
pillssql = psql.read_sql("SELECT transaction_date, buyer_dea_no, buyer_bus_act, buyer_name, buyer_city, buyer_zip, buyer_county, drug_name, quantity, (case when length(dosage_unit) > 1 then dosage_unit end) as dosage_unit, mme_conversion_factor FROM opioidsca", database)

# %% [markdown]
# ### To speed things up, try reading the from a tsv, not postgres

# %%
pills = pd.read_csv("/Users/mhustiles/Desktop/data/arcos-ca-statewide-itemized.tsv", sep='\t', header=0, low_memory=False)

# %%
pop = pd.read_csv("/Users/mhustiles/Desktop/data/ca-counties-pop-1970-2050.csv", sep=',', header=0, low_memory=False)

# %% [markdown]
# ### Read the tsv with proper data types: first on import — and then after

# %%
pills = pd.read_csv("/Users/mhustiles/Desktop/data/arcos-ca-statewide-itemized.tsv", sep='\t', header=0, low_memory=False, dtype={'BUYER_ZIP': 'str'})

# %%
pills['REPORTER_ZIP'] = pills.REPORTER_ZIP.astype(object)

# %%
pills['DRUG_CODE'] = pills.DRUG_CODE.astype(object)

# %% [markdown]
# ### Transform the original int64 date field to a usable date

# %%
pills['TRANSACTION_DATE'] = pd.to_datetime(pills['TRANSACTION_DATE'].astype('str'), format = '%m%d%Y')

# %% [markdown]
# ### Parse the date further to extact year and month in new fields

# %%
pills['TRANSACTION_DATE'] = pd.to_datetime(pills['TRANSACTION_DATE'])
pills['YEAR'], pills['MONTH'] = pills['TRANSACTION_DATE'].dt.year, pills['TRANSACTION_DATE'].dt.month

# %% [markdown]
# ### Change month, year fields to objects for grouping

# %%
pills['YEAR'] = pills.YEAR.astype(object)

# %%
pills['MONTH'] = pills.MONTH.astype(object)

# %% [markdown]
# ### A look at all the data types for each field in our data population frame

# %%
pop['year'] = pop.year.astype(object)
pop['fips'] = pop.fips.astype(object)
pop.dtypes
# Out:
# fips          object
# county        object
# year          object
# age            int64
# pop_female     int64
# pop_male       int64
# pop_total      int64
# dtype: object

# %% [markdown]
# ### A look at all the data types for each field in our pills data frame

# %%
pills.dtypes
# Out:
# REPORTER_DEA_NO                  object
# REPORTER_BUS_ACT                 object
# REPORTER_NAME                    object
# REPORTER_ADDL_CO_INFO            object
# REPORTER_ADDRESS1                object
# REPORTER_ADDRESS2                object
# REPORTER_CITY                    object
# REPORTER_STATE                   object
# REPORTER_ZIP                     object
# REPORTER_COUNTY                  object
# BUYER_DEA_NO                     object
# BUYER_BUS_ACT                    object
# BUYER_NAME                       object
# BUYER_ADDL_CO_INFO               object
# BUYER_ADDRESS1                   object
# BUYER_ADDRESS2                   object
# BUYER_CITY                       object
# BUYER_STATE                      object
# BUYER_ZIP                        object
# BUYER_COUNTY                     object
# TRANSACTION_CODE                 object
# DRUG_CODE                        object
# NDC_NO                           object
# DRUG_NAME                        object
# QUANTITY                        float64
# UNIT                            float64
# ACTION_INDICATOR                 object
# ORDER_FORM_NO                    object
# CORRECTION_NO                   float64
# STRENGTH                        float64
# TRANSACTION_DATE         datetime64[ns]
# CALC_BASE_WT_IN_GM              float64
# DOSAGE_UNIT                     float64
# TRANSACTION_ID                    int64
# Product_Name                     object
# Ingredient_Name                  object
# Measure                          object
# MME_Conversion_Factor           float64
# Combined_Labeler_Name            object
# Revised_Company_Name             object
# Reporter_family                  object
# dos_str                         float64
# YEAR                             object
# MONTH                            object
# dtype: object

# %%
years = [2006,2007,2008,2009,2010,2011,2012]
popyears = pop[pop.year.isin(years)]

# %%
popyearsadults = popyears[popyears.age > 17 ]

# %%
popyearsadults.head()
# Out:
#       fips   county  year  age  pop_female  pop_male  pop_total
# 3654  6001  ALAMEDA  2006   18        9848     10099      19947
# 3655  6001  ALAMEDA  2006   19        9684     10165      19849
# 3656  6001  ALAMEDA  2006   20       10053     10398      20451
# 3657  6001  ALAMEDA  2006   21       10189     10258      20447
# 3658  6001  ALAMEDA  2006   22       10335     10445      20780

# %%
popyears.head()
# Out:
#       fips   county  year  age  pop_female  pop_male  pop_total
# 3636  6001  ALAMEDA  2006    0        9570     10168      19738
# 3637  6001  ALAMEDA  2006    1        9601      9950      19551
# 3638  6001  ALAMEDA  2006    2        9625      9898      19523
# 3639  6001  ALAMEDA  2006    3        9578      9904      19482
# 3640  6001  ALAMEDA  2006    4        9571     10008      19579

# %%
# popyears.groupby(['year','county'])[['pop_total']].sum()
pillyears = popyearsadults.groupby(['year','county'], as_index=False).agg({"pop_total": "sum"})

# %%
pillyears.head()
# Out:
#    year     county  pop_total
# 0  2006    ALAMEDA    1112310
# 1  2006     ALPINE        996
# 2  2006     AMADOR      30667
# 3  2006      BUTTE     166403
# 4  2006  CALAVERAS      36225

# %% [markdown]
# ### How many people (should update to just adults) lived in each California county in each of the years from 2006 to 2012?

# %%
pillyears['county'] = pillyears['county'].astype(object)

# %%
pills['county'] = pills.BUYER_COUNTY.astype(object)

# %%
pills.head()
# Out:
#   REPORTER_DEA_NO REPORTER_BUS_ACT     REPORTER_NAME REPORTER_ADDL_CO_INFO  \
# 0       PA0021179      DISTRIBUTOR      APOTHECA INC                   NaN
# 1       PB0034861      DISTRIBUTOR  BELLCO DRUG CORP                   NaN
# 2       PB0034861      DISTRIBUTOR  BELLCO DRUG CORP                   NaN
# 3       PB0034861      DISTRIBUTOR  BELLCO DRUG CORP                   NaN
# 4       PB0034861      DISTRIBUTOR  BELLCO DRUG CORP                   NaN
#
#         REPORTER_ADDRESS1 REPORTER_ADDRESS2     REPORTER_CITY REPORTER_STATE  \
# 0          1622 N 16TH ST               NaN           PHOENIX             AZ
# 1  5500 NEW HORIZONS BLVD               NaN  NORTH AMITYVILLE             NY
# 2  5500 NEW HORIZONS BLVD               NaN  NORTH AMITYVILLE             NY
# 3  5500 NEW HORIZONS BLVD               NaN  NORTH AMITYVILLE             NY
# 4  5500 NEW HORIZONS BLVD               NaN  NORTH AMITYVILLE             NY
#
#   REPORTER_ZIP REPORTER_COUNTY  ...                          Ingredient_Name  \
# 0        85006        MARICOPA  ...  HYDROCODONE BITARTRATE HEMIPENTAHYDRATE
# 1        11701         SUFFOLK  ...  HYDROCODONE BITARTRATE HEMIPENTAHYDRATE
# 2        11701         SUFFOLK  ...  HYDROCODONE BITARTRATE HEMIPENTAHYDRATE
# 3        11701         SUFFOLK  ...  HYDROCODONE BITARTRATE HEMIPENTAHYDRATE
# 4        11701         SUFFOLK  ...  HYDROCODONE BITARTRATE HEMIPENTAHYDRATE
#
#   Measure MME_Conversion_Factor           Combined_Labeler_Name  \
# 0     TAB                   1.0                   Apotheca Inc.
# 1     TAB                   1.0                      SpecGx LLC
# 2     TAB                   1.0  Teva Pharmaceuticals USA, Inc.
# 3     TAB                   1.0              Par Pharmaceutical
# 4     TAB                   1.0            Actavis Pharma, Inc.
#
#          Revised_Company_Name   Reporter_family dos_str  YEAR MONTH     county
# 0               Apotheca Inc.      Apotheca Inc     5.0  2007     2    VENTURA
# 1                Mallinckrodt  Bellco Drug Corp     7.5  2006    11     ORANGE
# 2                        Teva  Bellco Drug Corp     7.5  2006    10     ORANGE
# 3  Endo Pharmaceuticals, Inc.  Bellco Drug Corp    10.0  2006     2  SAN DIEGO
# 4              Allergan, Inc.  Bellco Drug Corp     5.0  2006     3  SAN DIEGO
#
# [5 rows x 45 columns]

# %% [markdown]
# ### Merge our tables for pill by county and population by county

# %%
pillyears['year'] = pillyears.year.astype(object)
pillscounties['year'] = pillscounties.YEAR.astype(object)

# %%
merged = pd.merge(pillyears,pillscounties, on=['county','year'])

# %%
merged
# Out:
#       year   county  pop_total  YEAR BUYER_COUNTY        BUYER_BUS_ACT  \
# 0     2006  ALAMEDA    1464841  2006      ALAMEDA       CHAIN PHARMACY
# 1     2006  ALAMEDA    1464841  2006      ALAMEDA       CHAIN PHARMACY
# 2     2006  ALAMEDA    1464841  2006      ALAMEDA         PRACTITIONER
# 3     2006  ALAMEDA    1464841  2006      ALAMEDA         PRACTITIONER
# 4     2006  ALAMEDA    1464841  2006      ALAMEDA  PRACTITIONER-DW/100
# ...    ...      ...        ...   ...          ...                  ...
# 2543  2012     YUBA      73099  2012         YUBA       CHAIN PHARMACY
# 2544  2012     YUBA      73099  2012         YUBA       CHAIN PHARMACY
# 2545  2012     YUBA      73099  2012         YUBA         PRACTITIONER
# 2546  2012     YUBA      73099  2012         YUBA      RETAIL PHARMACY
# 2547  2012     YUBA      73099  2012         YUBA      RETAIL PHARMACY
#
#         DRUG_NAME  DOSAGE_UNIT       rate mapcounty
# 0     HYDROCODONE   13290980.0   9.073326   ALAMEDA
# 1       OXYCODONE    2273540.0   1.552073   ALAMEDA
# 2     HYDROCODONE    1585799.5   1.082574   ALAMEDA
# 3       OXYCODONE        800.0   0.000546   ALAMEDA
# 4     HYDROCODONE      41900.0   0.028604   ALAMEDA
# ...           ...          ...        ...       ...
# 2543  HYDROCODONE    2162470.0  29.582758      YUBA
# 2544    OXYCODONE     319700.0   4.373521      YUBA
# 2545  HYDROCODONE       1800.0   0.024624      YUBA
# 2546  HYDROCODONE    2368900.0  32.406736      YUBA
# 2547    OXYCODONE     412580.0   5.644126      YUBA
#
# [2548 rows x 10 columns]

# %% [markdown]
# ### Create a rate field in our merged table

# %%
merged['rate'] = merged['DOSAGE_UNIT']/merged['pop_total']

# %% [markdown]
# ### New merged table with county, drug, business type, pills, population and rate — sorted desc by rate
# ### (These places are the outliers)

# %%
merged.to_csv("/Users/mhustiles/Desktop/data/merged.csv", sep=',', encoding='utf-8')
print(merged)
# Out:
#       year   county  pop_total  YEAR BUYER_COUNTY        BUYER_BUS_ACT  \
# 0     2006  ALAMEDA    1464841  2006      ALAMEDA       CHAIN PHARMACY
# 1     2006  ALAMEDA    1464841  2006      ALAMEDA       CHAIN PHARMACY
# 2     2006  ALAMEDA    1464841  2006      ALAMEDA         PRACTITIONER
# 3     2006  ALAMEDA    1464841  2006      ALAMEDA         PRACTITIONER
# 4     2006  ALAMEDA    1464841  2006      ALAMEDA  PRACTITIONER-DW/100
# ...    ...      ...        ...   ...          ...                  ...
# 2543  2012     YUBA      73099  2012         YUBA       CHAIN PHARMACY
# 2544  2012     YUBA      73099  2012         YUBA       CHAIN PHARMACY
# 2545  2012     YUBA      73099  2012         YUBA         PRACTITIONER
# 2546  2012     YUBA      73099  2012         YUBA      RETAIL PHARMACY
# 2547  2012     YUBA      73099  2012         YUBA      RETAIL PHARMACY
#
#         DRUG_NAME  DOSAGE_UNIT       rate mapcounty
# 0     HYDROCODONE   13290980.0   9.073326   ALAMEDA
# 1       OXYCODONE    2273540.0   1.552073   ALAMEDA
# 2     HYDROCODONE    1585799.5   1.082574   ALAMEDA
# 3       OXYCODONE        800.0   0.000546   ALAMEDA
# 4     HYDROCODONE      41900.0   0.028604   ALAMEDA
# ...           ...          ...        ...       ...
# 2543  HYDROCODONE    2162470.0  29.582758      YUBA
# 2544    OXYCODONE     319700.0   4.373521      YUBA
# 2545  HYDROCODONE       1800.0   0.024624      YUBA
# 2546  HYDROCODONE    2368900.0  32.406736      YUBA
# 2547    OXYCODONE     412580.0   5.644126      YUBA
#
# [2548 rows x 10 columns]

# %%
merged.sort_values(by='rate', ascending=False)
# Out:
#       year          county  pop_total  YEAR    BUYER_COUNTY  \
# 2222  2012       DEL NORTE      28015  2012       DEL NORTE
# 1856  2011       DEL NORTE      28223  2011       DEL NORTE
# 2324  2012           MODOC       9633  2012           MODOC
# 1959  2011           MODOC       9682  2011           MODOC
# 1491  2010       DEL NORTE      28391  2010       DEL NORTE
# ...    ...             ...        ...   ...             ...
# 214   2006  SAN BERNARDINO    1976767  2006  SAN BERNARDINO
# 894   2008          ORANGE    2982789  2008          ORANGE
# 1625  2010          ORANGE    3014684  2010          ORANGE
# 2045  2011       SAN DIEGO    3135961  2011       SAN DIEGO
# 1258  2009          ORANGE    2998824  2009          ORANGE
#
#             BUYER_BUS_ACT    DRUG_NAME  DOSAGE_UNIT       rate
# 2222       CHAIN PHARMACY  HYDROCODONE    2039700.0  72.807425
# 1856       CHAIN PHARMACY  HYDROCODONE    2020910.0  71.605074
# 2324       CHAIN PHARMACY  HYDROCODONE     674090.0  69.977162
# 1959       CHAIN PHARMACY  HYDROCODONE     646890.0  66.813675
# 1491       CHAIN PHARMACY  HYDROCODONE    1871440.0  65.916664
# ...                   ...          ...          ...        ...
# 214          PRACTITIONER    OXYCODONE        100.0   0.000051
# 894    PRACTITIONER-DW/30    OXYCODONE        100.0   0.000034
# 1625   PRACTITIONER-DW/30    OXYCODONE        100.0   0.000033
# 2045  PRACTITIONER-DW/100    OXYCODONE        100.0   0.000032
# 1258   PRACTITIONER-DW/30    OXYCODONE         40.0   0.000013
#
# [2548 rows x 9 columns]

# %% [markdown]
# ### First three rows in our dataframe

# %%
pills.head(3)
# Out:
#   REPORTER_DEA_NO REPORTER_BUS_ACT     REPORTER_NAME REPORTER_ADDL_CO_INFO  \
# 0       PA0021179      DISTRIBUTOR      APOTHECA INC                   NaN
# 1       PB0034861      DISTRIBUTOR  BELLCO DRUG CORP                   NaN
# 2       PB0034861      DISTRIBUTOR  BELLCO DRUG CORP                   NaN
#
#         REPORTER_ADDRESS1 REPORTER_ADDRESS2     REPORTER_CITY REPORTER_STATE  \
# 0          1622 N 16TH ST               NaN           PHOENIX             AZ
# 1  5500 NEW HORIZONS BLVD               NaN  NORTH AMITYVILLE             NY
# 2  5500 NEW HORIZONS BLVD               NaN  NORTH AMITYVILLE             NY
#
#   REPORTER_ZIP REPORTER_COUNTY  ...                          Ingredient_Name  \
# 0        85006        MARICOPA  ...  HYDROCODONE BITARTRATE HEMIPENTAHYDRATE
# 1        11701         SUFFOLK  ...  HYDROCODONE BITARTRATE HEMIPENTAHYDRATE
# 2        11701         SUFFOLK  ...  HYDROCODONE BITARTRATE HEMIPENTAHYDRATE
#
#   Measure MME_Conversion_Factor           Combined_Labeler_Name  \
# 0     TAB                   1.0                   Apotheca Inc.
# 1     TAB                   1.0                      SpecGx LLC
# 2     TAB                   1.0  Teva Pharmaceuticals USA, Inc.
#
#   Revised_Company_Name   Reporter_family dos_str  YEAR MONTH   county
# 0        Apotheca Inc.      Apotheca Inc     5.0  2007     2  VENTURA
# 1         Mallinckrodt  Bellco Drug Corp     7.5  2006    11   ORANGE
# 2                 Teva  Bellco Drug Corp     7.5  2006    10   ORANGE
#
# [3 rows x 45 columns]

# %% [markdown]
# ### Buyers in LA County

# %%
lapills = pills[pills.BUYER_COUNTY == 'LOS ANGELES']

# %% [markdown]
# ### First three rows of LA pills dataframe

# %%
lapills.head(3)

# %% [markdown]
# ### Retail pharmarcies in the city of Los Angeles

# %%
pills[(pills.BUYER_CITY == 'LOS ANGELES') & (pills.BUYER_BUS_ACT == 'RETAIL PHARMACY')]

# %% [markdown]
# ### All transactions involving a buyer in zipcode 90066

# %%
pills[(pills.BUYER_ZIP == "90066")][['BUYER_NAME','BUYER_ZIP', 'BUYER_COUNTY', 'TRANSACTION_DATE']]

# %%
pills['DOSAGE_UNIT'].sum()

# %%
mpl.style.use('seaborn-poster')

# %%
def doplot():
    pills['BUYER_ZIP'].value_counts()[:10].plot(kind='barh')

mpl.style.use('ggplot')
doplot()

# %%
pills.head(5)

# %% [markdown]
# ### How many pills by type were sold in Los Angeles County over the years?

# %%
pills[pills.BUYER_COUNTY == 'LOS ANGELES'].groupby(['YEAR', 'DRUG_NAME'])[('DOSAGE_UNIT')].sum()

# %% [markdown]
# ### How did distribution of Oxycodone to California change over the time period?

# %%
def doplot():
    pills[(pills.DRUG_NAME == 'OXYCODONE')].groupby(['YEAR'])[('DOSAGE_UNIT')].sum().plot(kind='barh')

mpl.style.use('ggplot')
doplot()

# %% [markdown]
# ### What's the percentage change of oxycodone in CA during this time?

# %%
pillscounties = pills.groupby(['YEAR','BUYER_COUNTY', 'BUYER_BUS_ACT','DRUG_NAME'], as_index=False).agg({"DOSAGE_UNIT": "sum"})

# %%
pillscounties['county'] = pillscounties.BUYER_COUNTY.astype(object)

# %%
pillscounties
# Out:
#       YEAR BUYER_COUNTY        BUYER_BUS_ACT    DRUG_NAME  DOSAGE_UNIT  \
# 0     2006      ALAMEDA       CHAIN PHARMACY  HYDROCODONE   13290980.0
# 1     2006      ALAMEDA       CHAIN PHARMACY    OXYCODONE    2273540.0
# 2     2006      ALAMEDA         PRACTITIONER  HYDROCODONE    1585799.5
# 3     2006      ALAMEDA         PRACTITIONER    OXYCODONE        800.0
# 4     2006      ALAMEDA  PRACTITIONER-DW/100  HYDROCODONE      41900.0
# ...    ...          ...                  ...          ...          ...
# 2543  2012         YUBA       CHAIN PHARMACY  HYDROCODONE    2162470.0
# 2544  2012         YUBA       CHAIN PHARMACY    OXYCODONE     319700.0
# 2545  2012         YUBA         PRACTITIONER  HYDROCODONE       1800.0
# 2546  2012         YUBA      RETAIL PHARMACY  HYDROCODONE    2368900.0
# 2547  2012         YUBA      RETAIL PHARMACY    OXYCODONE     412580.0
#
#        county  year
# 0     ALAMEDA  2006
# 1     ALAMEDA  2006
# 2     ALAMEDA  2006
# 3     ALAMEDA  2006
# 4     ALAMEDA  2006
# ...       ...   ...
# 2543     YUBA  2012
# 2544     YUBA  2012
# 2545     YUBA  2012
# 2546     YUBA  2012
# 2547     YUBA  2012
#
# [2548 rows x 7 columns]

# %% [markdown]
# ### How did distribution of oxycodone to retail pharmacies change in the LA Times' zipcode over time?

# %%
def doplot():
    pills[(pills.BUYER_ZIP == '90066') & (pills.DRUG_NAME == 'OXYCODONE') & (pills.BUYER_BUS_ACT == 'RETAIL PHARMACY')].groupby(['YEAR'])[('DOSAGE_UNIT')].sum().plot.barh(y='YEAR')

mpl.style.use('ggplot')
doplot()

# %% [markdown]
# ### Who were the largest distributors in CA during the period?

# %% [markdown]
# ### How does pill distribution in California compare, per capita, with other states?

# %% [markdown]
# ### How does pill distribution in Los Angeles County compare, per capita, with other counties?

# %% [markdown]
# ### Which CA cities had the highest per capita pill distribution?

# %% [markdown]
# ### Oxy distribution to retail pharmacies in zipcode 90066 over time?

# %%
def doplot():
    pills[(pills.BUYER_ZIP == '90066') & (pills.DRUG_NAME == 'OXYCODONE') & (pills.BUYER_BUS_ACT == 'RETAIL PHARMACY')].groupby(['YEAR'])[('DOSAGE_UNIT')].sum().plot.barh(y='YEAR')
    
mpl.style.use('ggplot')
doplot()

# %%
camap = geopandas.read_file('/Users/mhustiles/Desktop/data/GIS/ca-counties.geojson')

# %%
camap.plot()

# %%
merged.head(1)
camap.head(1)
# Out:
#   CountyFIPS   FIPS    Name  \
# 0        059  06059  Orange
#
#                                             geometry mapcounty
# 0  (POLYGON ((-118.097404 33.77419, -118.097466 3...    Orange

# %%
camap['mapcounty'] = camap.Name.str.upper()
merged['mapcounty'] = merged.county.astype(object)

# %%
mappills = pd.merge(merged,camap, on=['mapcounty'])

# %%
mappills.tail(1)
# Out:
#       year county  pop_total  YEAR BUYER_COUNTY    BUYER_BUS_ACT  DRUG_NAME  \
# 2547  2012   YUBA      73099  2012         YUBA  RETAIL PHARMACY  OXYCODONE
#
#       DOSAGE_UNIT      rate mapcounty CountyFIPS   FIPS  Name  \
# 2547     412580.0  5.644126      YUBA        115  06115  Yuba
#
#                                                geometry
# 2547  (POLYGON ((-121.205602 39.312435, -121.205599 ...

# %%
variable = merged['rate']

# set the range for the choropleth
vmin, vmax = 0, 78


mappills.plot(geometry, scheme='quantiles', cmap='OrRd')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-178-58e8a11cecc4> in <module>
# ----> 1 mappills.plot(geometry, scheme='quantiles', cmap='OrRd')
#
# NameError: name 'geometry' is not defined
